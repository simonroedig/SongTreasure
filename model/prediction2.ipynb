# %% [markdown]
# - Grab new songs for genre from spotify -> feasible?
# - Run popularity prediction
# - Return sample

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lukas\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lukas\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lukas\appdata\roaming\python\python310\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lukas\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 23.3.1 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv('SpotifyFeatures.csv')
print(df.columns)
df.describe()
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# 25%         0.385000          0.000000       0.097400     -11.771000
# 50%         0.605000          0.000044       0.128000      -7.762000
# 75%         0.787000          0.035800       0.264000      -5.501000
# max         0.999000          0.999000       1.000000       3.744000
#
#          speechiness          tempo        valence
# count  232725.000000  232725.000000  232725.000000
# mean        0.120765     117.666585       0.454917
# std         0.185518      30.898907       0.260065
# min         0.022200      30.379000       0.000000
# 25%         0.036700      92.959000       0.237000
# 50%         0.050100     115.778000       0.444000
# 75%         0.105000     139.054000       0.660000
# max         0.967000     242.903000       1.000000

# %%
pd.isnull(df).sum()
# Out:
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
df["key_num"] = df["key"].astype('category').cat.codes
df["mode_num"] = df["mode"].astype('category').cat.codes
df["time_signature_num"] = df["time_signature"].astype('category').cat.codes

# %%
df.head(10)
# Out:
#    genre          artist_name  \
# 0  Movie       Henri Salvador
# 1  Movie    Martin & les fées
# 2  Movie      Joseph Williams
# 3  Movie       Henri Salvador
# 4  Movie         Fabien Nataf
# 5  Movie       Henri Salvador
# 6  Movie    Martin & les fées
# 7  Movie          Laura Mayne
# 8  Movie               Chorus
# 9  Movie  Le Club des Juniors
#
#                                           track_name                track_id  \
# 0                        C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1                   Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2                     Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3                     Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                          Ouverture  0IuslXpMROHdEPvSl1fTQK
# 5                     Le petit souper aux chandelles  0Mf1jKa8eNAf1a4PwTbizj
# 6  Premières recherches (par Paul Ventimila, Lori...  0NUiKYRd6jt1LKMYGkUdnZ
# 7                                      Let Me Let Go  0PbIF9YVD505GutwotpB5C
# 8                                              Helka  0ST6uPfvaPpJLtQwhE6KfC
# 9                          Les bisous des bisounours  0VSqZ3KStsjcfERGdcWpFO
#
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0           0       0.61100         0.389        99373  0.9100
# 1           1       0.24600         0.590       137373  0.7370
# 2           3       0.95200         0.663       170267  0.1310
# 3           0       0.70300         0.240       152427  0.3260
# 4           4       0.95000         0.331        82625  0.2250
# 5           0       0.74900         0.578       160627  0.0948
# 6           2       0.34400         0.703       212293  0.2700
# 7          15       0.93900         0.416       240067  0.2690
# 8           0       0.00104         0.734       226200  0.4810
# 9          10       0.31900         0.598       152694  0.7050
#
#    instrumentalness  ... liveness  loudness   mode speechiness    tempo  \
# 0           0.00000  ...   0.3460    -1.828  Major      0.0525  166.969
# 1           0.00000  ...   0.1510    -5.559  Minor      0.0868  174.003
# 2           0.00000  ...   0.1030   -13.879  Minor      0.0362   99.488
# 3           0.00000  ...   0.0985   -12.178  Major      0.0395  171.758
# 4           0.12300  ...   0.2020   -21.150  Major      0.0456  140.576
# 5           0.00000  ...   0.1070   -14.970  Major      0.1430   87.479
# 6           0.00000  ...   0.1050   -12.675  Major      0.9530   82.873
# 7           0.00000  ...   0.1130    -8.949  Major      0.0286   96.827
# 8           0.00086  ...   0.0765    -7.725  Major      0.0460  125.080
# 9           0.00125  ...   0.3490    -7.790  Major      0.0281  137.496
#
#    time_signature valence  key_num  mode_num  time_signature_num
# 0             4/4   0.814        4         0                   3
# 1             4/4   0.816        9         1                   3
# 2             5/4   0.368        3         1                   4
# 3             4/4   0.227        4         0                   3
# 4             4/4   0.390        8         0                   3
# 5             4/4   0.358        4         0                   3
# 6             4/4   0.533        4         0                   3
# 7             4/4   0.274        9         0                   3
# 8             4/4   0.765        3         0                   3
# 9             4/4   0.718       10         0                   3
#
# [10 rows x 21 columns]

# %%
# Deal with NaN
df = df.dropna()
# Deal with duplicates

# Deal with data normalization

# %%
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "liveness", "loudness", "speechiness", "tempo", "valence", "key_num", "mode_num", "time_signature_num"]

# %%
x = df[features]
y = df["popularity"]

# %%
#normalize x values
x = (x - x.mean()) / x.std()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
len(x_train)
# Out:
# 186179

# %%
x_train = x_train[:100000]
y_train = y_train[:100000]

x_test = x_test[:100000]
y_test = y_test[:100000]

# %%
# do a linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import tensorflow as tf
from tensorflow import keras

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(mean_squared_error(y_test, y_pred))

# do a random forest

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(mean_squared_error(y_test, y_pred))

# do a neural network

model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=[len(features)]),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')

model.fit(x_train, y_train, epochs=100)

y_pred = model.predict(x_test)

mean_squared_error(y_test, y_pred)
# Out:
# 266.7881072584992
# 241.7728407
# Epoch 1/100
# c:\Users\lukas\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1912.4507
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1111.2971
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 367.1723
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 304.3248
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 299.7274
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 274.6755
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 269.2203
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 260.7921
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 257.3313
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 265.3615
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 229.4232
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 226.6159
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 235.5196
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 221.7026
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 222.0446
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 215.5645
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 210.5931
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 217.6747
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 213.4271
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 197.8924
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 189.8799
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 194.1326
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 188.1826
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 188.1942
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 191.9186
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 164.8895
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 174.3085
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 180.2399
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 176.2891
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 179.3191
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 155.3188
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 161.4689
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 147.4719
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 147.7353
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 151.0065
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 136.0589
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 135.2857
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 145.0650
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 134.5906
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 136.7948
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 117.4118
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 117.5224
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 128.5025
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 113.7446
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 115.2831
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 122.8040
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 115.2439
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 104.4755
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 104.7641
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 105.6000
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 104.6625
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 100.9329
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 102.2147
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 90.7901
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84.2220
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 82.1458
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 100.4039
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 90.9981
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 81.4234
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 78.7405
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 86.2228
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 82.0559
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 78.8408
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 71.7948
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 71.2770
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 77.0123
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 77.0852
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 68.7723
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.8610
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 65.0686
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 71.6687
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 64.7605
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 59.8213
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 54.5168
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 52.8843
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 60.9837
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49.7142
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 51.6401
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 53.7346
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 50.4071
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49.0425
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.0728
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47.1321
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 46.7093
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 43.4121
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 45.0467
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.7206
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40.1755
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.5843
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 38.0693
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.6562
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 30.2973
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 44.0650
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 39.0684
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.0615
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.2702
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28.5844
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 33.9837
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 33.0002
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28.0361
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 417.2128009334604

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# client_id = ''
# client_secret = ''

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id, client_secret))

# Get a list of new releases
new_releases = spotify.new_releases('US', limit=50)
albums = new_releases['albums']['items']

for album in albums:
   # Get the artists on the album
   artists = album['artists']
   for artist in artists:
      # Get the genres for the artist
      artist_info = spotify.artist(artist['id'])
      genres = artist_info['genres']

      # If the desired genre is in the artist's genres, print their name
      if 'pop' in genres:
         print(artist['name'])
# Out:
# Kygo
# Kehlani
# Normani
# Charli xcx
# Meghan Trainor
# Twenty One Pilots
# Billie Eilish
# ZAYN
# Galantis

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = 'your client id'
client_secret = 'your client secret'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id, client_secret))

# specify the preferred genre
preferred_genre = 'pop'

# Get a list of new releases
new_releases = spotify.new_releases('US', limit=50)
albums = new_releases['albums']['items']
track_list = []

# Go through each album
for album in albums:
    album_id = album['id']
    tracks = spotify.album_tracks(album_id)
    for track in tracks['items']:
        artists = track['artists']
        for artist in artists:
            artist_info = spotify.artist(artist['id'])
            genres = artist_info['genres']

            # If the preferred genre is in the artist genres, get the features of the song
            if preferred_genre in genres:
                features = spotify.audio_features([track['id']])
                track_list.append({'name': track['name'], 'features': features})

            # If the track list is more than 10, return it
            if len(track_list) > 10:
                break
        if len(track) > 10:
            break
    if len(track_list) > 10:
            break

for track in track_list:
     print(track)
# Out:
# {'name': 'Intro', 'features': [{'danceability': 0.555, 'energy': 0.379, 'key': 3, 'loudness': -15.828, 'mode': 0, 'speechiness': 0.0334, 'acousticness': 0.922, 'instrumentalness': 0.789, 'liveness': 0.134, 'valence': 0.14, 'tempo': 102.114, 'type': 'audio_features', 'id': '2vvWBH2VnScjAuFzNjdoxX', 'uri': 'spotify:track:2vvWBH2VnScjAuFzNjdoxX', 'track_href': 'https://api.spotify.com/v1/tracks/2vvWBH2VnScjAuFzNjdoxX', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vvWBH2VnScjAuFzNjdoxX', 'duration_ms': 75709, 'time_signature': 4}]}
# {'name': 'GrooveTheory', 'features': [{'danceability': 0.372, 'energy': 0.578, 'key': 6, 'loudness': -6.408, 'mode': 0, 'speechiness': 0.1, 'acousticness': 0.214, 'instrumentalness': 0.000147, 'liveness': 0.186, 'valence': 0.479, 'tempo': 66.248, 'type': 'audio_features', 'id': '5oxUDQOmmC7hAzv9wWvvDA', 'uri': 'spotify:track:5oxUDQOmmC7hAzv9wWvvDA', 'track_href': 'https://api.spotify.com/v1/tracks/5oxUDQOmmC7hAzv9wWvvDA', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5oxUDQOmmC7hAzv9wWvvDA', 'duration_ms': 247729, 'time_signature': 4}]}
# {'name': 'Big Boy (feat. Starrah)', 'features': [{'danceability': 0.75, 'energy': 0.782, 'key': 1, 'loudness': -5.847, 'mode': 1, 'speechiness': 0.144, 'acousticness': 0.0417, 'instrumentalness': 0.000103, 'liveness': 0.074, 'valence': 0.878, 'tempo': 167.933, 'type': 'audio_features', 'id': '6617OvEesvCz7kGfXLYW4h', 'uri': 'spotify:track:6617OvEesvCz7kGfXLYW4h', 'track_href': 'https://api.spotify.com/v1/tracks/6617OvEesvCz7kGfXLYW4h', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6617OvEesvCz7kGfXLYW4h', 'duration_ms': 173087, 'time_signature': 4}]}
# {'name': '360', 'features': [{'danceability': 0.857, 'energy': 0.62, 'key': 0, 'loudness': -8.13, 'mode': 1, 'speechiness': 0.0472, 'acousticness': 0.646, 'instrumentalness': 0.244, 'liveness': 0.0934, 'valence': 0.796, 'tempo': 120.042, 'type': 'audio_features', 'id': '4w2GLmK2wnioVnb5CPQeex', 'uri': 'spotify:track:4w2GLmK2wnioVnb5CPQeex', 'track_href': 'https://api.spotify.com/v1/tracks/4w2GLmK2wnioVnb5CPQeex', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4w2GLmK2wnioVnb5CPQeex', 'duration_ms': 133805, 'time_signature': 4}]}
# {'name': 'To The Moon', 'features': [{'danceability': 0.609, 'energy': 0.527, 'key': 6, 'loudness': -6.052, 'mode': 1, 'speechiness': 0.0512, 'acousticness': 0.144, 'instrumentalness': 8.86e-06, 'liveness': 0.357, 'valence': 0.574, 'tempo': 134.909, 'type': 'audio_features', 'id': '6jKDpPlWDdR5NGaFHspAfP', 'uri': 'spotify:track:6jKDpPlWDdR5NGaFHspAfP', 'track_href': 'https://api.spotify.com/v1/tracks/6jKDpPlWDdR5NGaFHspAfP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6jKDpPlWDdR5NGaFHspAfP', 'duration_ms': 148666, 'time_signature': 4}]}
# {'name': 'Overcompensate', 'features': [{'danceability': 0.363, 'energy': 0.891, 'key': 5, 'loudness': -5.563, 'mode': 0, 'speechiness': 0.0978, 'acousticness': 0.00992, 'instrumentalness': 0.00183, 'liveness': 0.134, 'valence': 0.331, 'tempo': 95.089, 'type': 'audio_features', 'id': '1LAlLBTGBUO0MDA8IbSysd', 'uri': 'spotify:track:1LAlLBTGBUO0MDA8IbSysd', 'track_href': 'https://api.spotify.com/v1/tracks/1LAlLBTGBUO0MDA8IbSysd', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1LAlLBTGBUO0MDA8IbSysd', 'duration_ms': 236000, 'time_signature': 4}]}
# {'name': 'SKINNY', 'features': [{'danceability': 0.251, 'energy': 0.252, 'key': 9, 'loudness': -14.478, 'mode': 1, 'speechiness': 0.0375, 'acousticness': 0.693, 'instrumentalness': 0.00706, 'liveness': 0.0968, 'valence': 0.0395, 'tempo': 69.988, 'type': 'audio_features', 'id': '1CsMKhwEmNnmvHUuO5nryA', 'uri': 'spotify:track:1CsMKhwEmNnmvHUuO5nryA', 'track_href': 'https://api.spotify.com/v1/tracks/1CsMKhwEmNnmvHUuO5nryA', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CsMKhwEmNnmvHUuO5nryA', 'duration_ms': 219733, 'time_signature': 4}]}
# {'name': 'Dreamin', 'features': [{'danceability': 0.461, 'energy': 0.473, 'key': 4, 'loudness': -6.731, 'mode': 1, 'speechiness': 0.0504, 'acousticness': 0.43, 'instrumentalness': 0, 'liveness': 0.363, 'valence': 0.423, 'tempo': 176.05, 'type': 'audio_features', 'id': '24VNenhLzKDWDlQ5Qaznav', 'uri': 'spotify:track:24VNenhLzKDWDlQ5Qaznav', 'track_href': 'https://api.spotify.com/v1/tracks/24VNenhLzKDWDlQ5Qaznav', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24VNenhLzKDWDlQ5Qaznav', 'duration_ms': 212213, 'time_signature': 4}]}
# {'name': 'Dust', 'features': [{'danceability': 0.492, 'energy': 0.841, 'key': 1, 'loudness': -3.91, 'mode': 0, 'speechiness': 0.0573, 'acousticness': 0.0683, 'instrumentalness': 1.82e-06, 'liveness': 0.352, 'valence': 0.196, 'tempo': 124.942, 'type': 'audio_features', 'id': '3Q8NY0fH0T1tE4oqZ3S6fA', 'uri': 'spotify:track:3Q8NY0fH0T1tE4oqZ3S6fA', 'track_href': 'https://api.spotify.com/v1/tracks/3Q8NY0fH0T1tE4oqZ3S6fA', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Q8NY0fH0T1tE4oqZ3S6fA', 'duration_ms': 169506, 'time_signature': 4}]}
